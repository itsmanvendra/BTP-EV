# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df4 = pd.read_csv('withSOCOnlyOptimizedTotalTime.csv')

# %%
df1 = pd.read_csv('withSOCOptimizedTotalTime.csv')

# %%
df3 = pd.read_csv('withoutOptimization.csv')

# %%
df2 = pd.read_csv('withOptimization.csv')

# %%
first_row = df1.iloc[0]
ll = first_row.tolist()
lt = eval(ll[0])

xaxis = np.arange(0, len(lt), 1)
first_rrow = df4.iloc[0]
ll4 = first_rrow.tolist()
lxt = eval(ll4[0])

xaxis4 = np.arange(0, len(lxt), 1)

firstt_row = df2.iloc[0]
lll = firstt_row.tolist()
ltt = eval(lll[0])
xaxis1 = np.arange(0, len(ltt), 1)
firsttt_row = df3.iloc[0]
lllm = firsttt_row.tolist()
lttt = eval(lllm[0])
xaxis2 = np.arange(0, len(lttt), 1)
# increase the size of the plot
plt.figure(figsize=(20, 5))
plt.plot(xaxis, lt, label = "With Optimization(soc and dest)", color = 'blue')
plt.plot(xaxis4, lxt, label = "With Optimization(soc)", color = 'lightblue')
plt.plot(xaxis1, ltt, label = "With Optimization(range 5 km)", color = 'red')
# plt.plot(xaxis2, lttt, label = "Without Optimization", color = "lightgreen")
plt.xlabel('Requests')
plt.ylabel('Tottal Time(in seconds)')
plt.title('Total Time vs Request for 1st hour')
plt.legend()

# %%
first_row = df1.iloc[5]
ll = first_row.tolist()
lt = eval(ll[0])

xaxis = np.arange(0, len(lt), 1)
first_rrow = df4.iloc[5]
ll4 = first_rrow.tolist()
lxt = eval(ll4[0])

xaxis4 = np.arange(0, len(lxt), 1)

firstt_row = df2.iloc[5]
lll = firstt_row.tolist()
ltt = eval(lll[0])
xaxis1 = np.arange(0, len(ltt), 1)
firsttt_row = df3.iloc[5]
lllm = firsttt_row.tolist()
lttt = eval(lllm[0])
xaxis2 = np.arange(0, len(lttt), 1)
# increase the size of the plot
plt.figure(figsize=(20, 5))
plt.plot(xaxis, lt, label = "With Optimization(soc and dest)", color = 'blue')
plt.plot(xaxis4, lxt, label = "With Optimization(soc)", color = "lightblue")
plt.plot(xaxis1, ltt, label = "With Optimization(range 5 km)", color = 'red')
# plt.plot(xaxis2, lttt, label = "Without Optimization", color = 'lightgreen')
plt.xlabel('Requests Id')
plt.ylabel('TotalTime(in seconds)')
plt.title('Total Time vs Request for 6th hour')
plt.legend()

# %%
first_row = df1.iloc[12]
ll = first_row.tolist()
lt = eval(ll[0])

xaxis = np.arange(0, len(lt), 1)
first_rrow = df4.iloc[12]
ll4 = first_rrow.tolist()
lxt = eval(ll4[0])

xaxis4 = np.arange(0, len(lxt), 1)

firstt_row = df2.iloc[12]
lll = firstt_row.tolist()
ltt = eval(lll[0])
xaxis1 = np.arange(0, len(ltt), 1)
firsttt_row = df3.iloc[12]
lllm = firsttt_row.tolist()
lttt = eval(lllm[0])
xaxis2 = np.arange(0, len(lttt), 1)
# increase the size of the plot
plt.figure(figsize=(20, 5))
plt.plot(xaxis, lt, label = "With Optimization(soc and dest)", color = 'blue')
plt.plot(xaxis4, lxt, label = "With Optimization(soc)", color = "lightgreen")
plt.plot(xaxis1, ltt, label = "With Optimization(range 5 km)", color = 'red')
# plt.plot(xaxis2, lttt, label = "Without Optimization", color = 'lightblue')
plt.xlabel('Requests')
plt.ylabel('TotalTime(in seconds)')
plt.title(' Total Time vs Request for 13th hour')
plt.legend()

# %%
first_row = df1.iloc[19]
ll = first_row.tolist()
lt = eval(ll[0])

xaxis = np.arange(0, len(lt), 1)
first_rrow = df4.iloc[19]
ll4 = first_rrow.tolist()
lxt = eval(ll4[0])

xaxis4 = np.arange(0, len(lxt), 1)

firstt_row = df2.iloc[9]
lll = firstt_row.tolist()
ltt = eval(lll[0])
xaxis1 = np.arange(0, len(ltt), 1)
firsttt_row = df3.iloc[19]
lllm = firsttt_row.tolist()
lttt = eval(lllm[0])
xaxis2 = np.arange(0, len(lttt), 1)
# increase the size of the plot
plt.figure(figsize=(15, 4))
plt.plot(xaxis, lt, label = "With Optimization(soc and dest)", color = 'blue')
plt.plot(xaxis4, lxt, label = "With Optimization(soc)", color = "green")
plt.plot(xaxis1, ltt, label = "With Optimization(range 5 km)", color = 'red')
plt.plot(xaxis2, lttt, label = "Without Optimization", color = 'pink')
plt.xlabel('Requests')
plt.ylabel('waitTime(in seconds)')
plt.title('optimized model for 20th hour')
plt.legend()

# %%
first_row = df1.iloc[22]
ll = first_row.tolist()
lt = eval(ll[0])

xaxis = np.arange(0, len(lt), 1)
first_rrow = df4.iloc[22]
ll4 = first_rrow.tolist()
lxt = eval(ll4[0])

xaxis4 = np.arange(0, len(lxt), 1)

firstt_row = df2.iloc[22]
lll = firstt_row.tolist()
ltt = eval(lll[0])
xaxis1 = np.arange(0, len(ltt), 1)
firsttt_row = df3.iloc[22]
lllm = firsttt_row.tolist()
lttt = eval(lllm[0])
xaxis2 = np.arange(0, len(lttt), 1)

# increase the size of the plot
plt.figure(figsize=(15, 4))
plt.plot(xaxis, lt, label = "With Optimization(soc and dest)", color = 'blue')
plt.plot(xaxis4, lxt, label = "With Optimization(soc)", color = "green")
plt.plot(xaxis1, ltt, label = "With Optimization(range 5 km)", color = 'red')
plt.plot(xaxis2, lttt, label = "Without Optimization", color = 'pink')
plt.xlabel('Requests')
plt.ylabel('waitTime(in seconds)')
plt.title('optimized model for 23nd hour')
plt.legend()
