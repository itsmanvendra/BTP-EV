# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasetWithOptimization.csv')

# %%
df2 = pd.read_csv('datasetWithoutOptimization.csv')

# %%
firstrow = df.iloc[0]
list_row = firstrow.tolist()[1:]
first_row = df2.iloc[0]
list__row = first_row.tolist()[1:]
xaxis = np.arange(0,24,1)
plt.plot(xaxis,list_row,label = "With Optimization",color='red',)
plt.plot(xaxis,list__row,label = "Without Optimization",color='blue')
plt.xlabel('Time Of Day (hours)')
plt.ylabel('Average Time (seconds)')
plt.title('Average Wating Time For Charging Stations CS00')
plt.legend()

# %%
firstrow = df.iloc[6]
list_row = firstrow.tolist()[1:]
first_row = df2.iloc[6]
list__row = first_row.tolist()[1:]
xaxis = np.arange(0,24,1)

plt.plot(xaxis,list_row,label = "With Optimization",color='red',)
plt.plot(xaxis,list__row,label = "Without Optimization",color='blue')
plt.xlabel('Time Of Day (hours)')
plt.ylabel('Average Time (seconds)')
plt.title('Average Wating Time For Charging Stations CS22')
plt.legend()

# %%
firstrow = df.iloc[9]
list_row = firstrow.tolist()[1:]
first_row = df2.iloc[9]
list__row = first_row.tolist()[1:]
xaxis = np.arange(0,24,1)

plt.plot(xaxis,list_row,label = "With Optimization",color='red',)
plt.plot(xaxis,list__row,label = "Without Optimization",color='blue')
plt.xlabel('Time Of Day (hours)')
plt.ylabel('Average Time (seconds)')
plt.title('Average Wating Time For Charging Stations CS28')
plt.legend()

# %%
firstrow = df.iloc[19]
list_row = firstrow.tolist()[1:]
first_row = df2.iloc[19]
list__row = first_row.tolist()[1:]
xaxis = np.arange(0,24,1)

plt.plot(xaxis,list_row,label = "With Optimization",color='red',)
plt.plot(xaxis,list__row,label = "Without Optimization",color='blue')
plt.xlabel('Time Of Day (hours)')
plt.ylabel('Average Time (seconds)')
plt.title('Average Wating Time For Charging Stations CS68')
plt.legend()

# %%
firstrow = df.iloc[22]
list_row = firstrow.tolist()[1:]
first_row = df2.iloc[22]
list__row = first_row.tolist()[1:]
xaxis = np.arange(0,24,1)

plt.plot(xaxis,list_row,label = "With Optimization",color='red',)
plt.plot(xaxis,list__row,label = "Without Optimization",color='blue')
plt.xlabel('Time Of Day (hours)')
plt.ylabel('Average Time (seconds)')
plt.title('Average Wating Time For Charging Stations CS84')
plt.legend()

# %%
cs00 = df.iloc[0]
cs00 = cs00.tolist()[1:]
cs22 = df.iloc[6]
cs22 = cs22.tolist()[1:]
cs28 = df.iloc[9]
cs28 = cs28.tolist()[1:]
cs68 = df.iloc[19]
cs68 = cs68.tolist()[1:]
cs84 = df.iloc[22]
cs84 = cs84.tolist()[1:]
xaxis = np.arange(0,24,1)
plt.plot(xaxis,cs00,label = "CS00",color='red')
plt.plot(xaxis,cs22,label = "CS22",color='blue')
plt.plot(xaxis,cs28,label = "CS28",color='green')
plt.plot(xaxis,cs68,label = "CS68",color='orange')
plt.plot(xaxis,cs84,label = "CS84",color='purple')
plt.xlabel('Time Of Day (hours)')
plt.ylabel('Average Time (seconds)')
plt.title('Average Wating Time For Charging Stations')
plt.legend()

# %%
cs00 = df2.iloc[0]
cs00 = cs00.tolist()[1:]
cs22 = df2.iloc[6]
cs22 = cs22.tolist()[1:]
cs28 = df2.iloc[9]
cs28 = cs28.tolist()[1:]
cs68 = df2.iloc[19]
cs68 = cs68.tolist()[1:]
cs84 = df2.iloc[22]
cs84 = cs84.tolist()[1:]
xaxis = np.arange(0,24,1)
plt.plot(xaxis,cs00,label = "CS00",color='red')
plt.plot(xaxis,cs22,label = "CS22",color='blue')
plt.plot(xaxis,cs28,label = "CS28",color='green')
plt.plot(xaxis,cs68,label = "CS68",color='orange')
plt.plot(xaxis,cs84,label = "CS84",color='purple')
plt.xlabel('Time Of Day (hours)')
plt.ylabel('Average Time (seconds)')
plt.title('Average Wating Time For Charging Stations')
plt.legend()
